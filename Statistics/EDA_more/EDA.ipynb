# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('HRDataset_v14.csv')

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
# sns.countplot(df['PerformanceScore'])
sns.countplot(x = 'PerformanceScore', data=df)
# Out:
# <Axes: xlabel='PerformanceScore', ylabel='count'>

# %%
df['RecruitmentSource'].value_counts()
# Out:
# RecruitmentSource
# Indeed                     87
# LinkedIn                   76
# Google Search              49
# Employee Referral          31
# Diversity Job Fair         29
# CareerBuilder              23
# Website                    13
# Other                       2
# On-line Web application     1
# Name: count, dtype: int64

# %%
sns.countplot(x = 'RecruitmentSource', hue= 'PerformanceScore', data=df)
# Out:
# <Axes: xlabel='RecruitmentSource', ylabel='count'>

# %%
x, y = 'RecruitmentSource', 'PerformanceScore'
df.groupby(x)[y].value_counts(normalize=True).mul(100).rename('percent').reset_index()
# Out:
#           RecruitmentSource   PerformanceScore     percent
# 0             CareerBuilder        Fully Meets   73.913043
# 1             CareerBuilder  Needs Improvement   17.391304
# 2             CareerBuilder            Exceeds    8.695652
# 3        Diversity Job Fair        Fully Meets   62.068966
# 4        Diversity Job Fair            Exceeds   20.689655
# 5        Diversity Job Fair  Needs Improvement   13.793103
# 6        Diversity Job Fair                PIP    3.448276
# 7         Employee Referral        Fully Meets   80.645161
# 8         Employee Referral            Exceeds   16.129032
# 9         Employee Referral                PIP    3.225806
# 10            Google Search        Fully Meets   87.755102
# 11            Google Search  Needs Improvement    6.122449
# 12            Google Search            Exceeds    4.081633
# 13            Google Search                PIP    2.040816
# 14                   Indeed        Fully Meets   75.862069
# ...

# %%
x, y = 'RecruitmentSource', 'PerformanceScore'
(df.groupby(x)[y].value_counts(normalize=True).mul(100).rename('percent').reset_index().pipe((sns.catplot,'data'), x=x, y='percent', hue = y, kind = 'bar', aspect =2))

# %%
# Here by salary and EngagementSurvey we can't determine anything about the data but when we apply the PerformanceScore as hue we can see that when EngagementSurvey is lower performancescore is like need to improve or PIP. So, form this we learn the when we add some dimention in our plot at that time We may reveal the data insight what we want.
sns.scatterplot(x = "Salary", y = "EngagementSurvey", data=df, hue='PerformanceScore')
# Out:
# <Axes: xlabel='Salary', ylabel='EngagementSurvey'>

# %%
p = sns.scatterplot(x = "Salary", y = "EngagementSurvey", data=df, hue='PerformanceScore')
p.set(xlim = (None, 120000))
# Out:
# [(34798.3, 120000.0)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df['Department'].value_counts()
# Out:
# Department
# Production              209
# IT/IS                    50
# Sales                    31
# Software Engineering     11
# Admin Offices             9
# Executive Office          1
# Name: count, dtype: int64

# %%
# To add an extra variable we can add style tag for give each category a different shape
p = sns.scatterplot(x = "Salary", y = "EngagementSurvey", data=df, hue='PerformanceScore', style = 'Department', size="EmpSatisfaction")
p.set(xlim = (None, 120000))
# Out:
# [(34798.3, 120000.0)]

# %%
df.Termd.value_counts()
# Out:
# Termd
# 0    207
# 1    104
# Name: count, dtype: int64

# %%
g = sns.FacetGrid(df, row ="Termd", hue="PerformanceScore", height=4, aspect=2)
g.map(sns.scatterplot, "Salary", "EngagementSurvey")
g.set(xlim=(None, 120000))

# %%
g = sns.FacetGrid(df, row ="MaritalDesc", hue="PerformanceScore", height=4, aspect=2)
g.map(sns.scatterplot, "Salary", "EngagementSurvey")
g.set(xlim=(None, 120000))

# %%
g = sns.FacetGrid(df, row ="MaritalDesc",col="Sex", hue="PerformanceScore", height=3, aspect=2)
g.map(sns.scatterplot, "Salary", "EngagementSurvey")
g.set(xlim=(None, 120000))

# %% [markdown]
# # Here from this dataset name (HRDataSet_14) we can say that there is a huge relationship between EngagementSurvey and Performance Imporvement
#
# ### EngagementSurvey mean an employee how much happy or sad with is job

# %%
df.EmpSatisfaction.value_counts()
# Out:
# EmpSatisfaction
# 3    108
# 5     98
# 4     94
# 2      9
# 1      2
# Name: count, dtype: int64

# %%
movie = pd.read_csv('movies_metadata.csv')
# Out:
# C:\Users\sangram.samanta\AppData\Local\Temp\ipykernel_1664\1202723107.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movie = pd.read_csv('movies_metadata.csv')

# %%
movie.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
mov2 = movie[['vote_average', 'vote_count', 'release_date']]

# %%
mov2 = mov2.dropna()

# %%
mov2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45376 entries, 0 to 45465
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   vote_average  45376 non-null  float64
#  1   vote_count    45376 non-null  float64
#  2   release_date  45376 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 1.4+ MB

# %%
mov2['date'] = pd.to_datetime(mov2['release_date'])

# %%
mov2.head()
# Out:
#    vote_average  vote_count release_date       date
# 0           7.7      5415.0   1995-10-30 1995-10-30
# 1           6.9      2413.0   1995-12-15 1995-12-15
# 2           6.5        92.0   1995-12-22 1995-12-22
# 3           6.1        34.0   1995-12-22 1995-12-22
# 4           5.7       173.0   1995-02-10 1995-02-10

# %%
mov2['year'] = mov2.date.dt.year

# %%
mov2.index = mov2['date']

# %%
mov2.head()
# Out:
#             vote_average  vote_count release_date       date  year
# date
# 1995-10-30           7.7      5415.0   1995-10-30 1995-10-30  1995
# 1995-12-15           6.9      2413.0   1995-12-15 1995-12-15  1995
# 1995-12-22           6.5        92.0   1995-12-22 1995-12-22  1995
# 1995-12-22           6.1        34.0   1995-12-22 1995-12-22  1995
# 1995-02-10           5.7       173.0   1995-02-10 1995-02-10  1995

# %%
fig, ax = plt.subplots()
ax = mov2.vote_average.plot(label='Average rating by year')

# %%
sns.boxplot(x='year', y='vote_average', data=mov2)
# Out:
# <Axes: xlabel='year', ylabel='vote_average'>

# %%
mov3 = mov2[mov2['year'] > 1990]

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x='year', y='vote_average', data=mov3, hue='year')
# Out:
# <Axes: xlabel='year', ylabel='vote_average'>

# %%
fig, ax = plt.subplots()

ax = mov3.vote_average.plot(label='Average rating by year', ax=ax)

# %%
fig, ax = plt.subplots(figsize=(16, 8))  # Set the figure size
ax = mov3.vote_average.plot(label='Average rating by year', ax=ax)
ax.set_xlabel('Year')
ax.set_ylabel('Average Rating')
ax.set_title('Average Movie Rating by Year')
ax.legend()

# %%
# black and white movies are good or colored movies are good
mov4 = mov2[(mov2['year'] > 1970) & (mov2['year'] < 1985)]

# %%
plt.figure(figsize=(16, 8))
sns.boxplot(x='year', y='vote_average', data=mov4, hue='year')
# Out:
# <Axes: xlabel='year', ylabel='vote_average'>
