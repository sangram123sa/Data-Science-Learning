# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/SachinScaler/May25_Intro_to_ML_NN/refs/heads/main/cars24-car-price.csv')

# %%
df.head()
# Out:
#    selling_price    year  km_driven  mileage  engine  max_power   age  \
# 0           1.20  2012.0     120000    19.70   796.0      46.30  11.0
# 1           5.50  2016.0      20000    18.90  1197.0      82.00   7.0
# 2           2.15  2010.0      60000    17.00  1197.0      80.00  13.0
# 3           2.26  2012.0      37000    20.92   998.0      67.10  11.0
# 4           5.70  2015.0      30000    22.77  1498.0      98.59   8.0
#
#       make                                      model  Individual  \
# 0   MARUTI                                   ALTO STD           1
# 1  HYUNDAI                             GRAND I10 ASTA           1
# 2  HYUNDAI                                   I20 ASTA           1
# 3   MARUTI                     ALTO K10 2010-2014 VXI           1
# 4     FORD  ECOSPORT 2015-2021 1.5 TDCI TITANIUM BSIV           0
#
#    Trustmark Dealer  Diesel  Electric  LPG  Petrol  Manual  5  >5
# 0                 0       0         0    0       1       1  1   0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19820 entries, 0 to 19819
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   selling_price     19820 non-null  float64
#  1   year              19820 non-null  float64
#  2   km_driven         19820 non-null  int64
#  3   mileage           19820 non-null  float64
#  4   engine            19820 non-null  float64
#  5   max_power         19820 non-null  float64
#  6   age               19820 non-null  float64
#  7   make              19820 non-null  object
#  8   model             19820 non-null  object
#  9   Individual        19820 non-null  int64
#  10  Trustmark Dealer  19820 non-null  int64
#  11  Diesel            19820 non-null  int64
#  12  Electric          19820 non-null  int64
#  13  LPG               19820 non-null  int64
#  14  Petrol            19820 non-null  int64
#  15  Manual            19820 non-null  int64
# ...

# %%
# Here I want to add a column full_name
df['full_name'] = df['make'] + ' ' + df['model']
df.head()
# Out:
#    selling_price    year  km_driven  mileage  engine  max_power   age  \
# 0           1.20  2012.0     120000    19.70   796.0      46.30  11.0
# 1           5.50  2016.0      20000    18.90  1197.0      82.00   7.0
# 2           2.15  2010.0      60000    17.00  1197.0      80.00  13.0
# 3           2.26  2012.0      37000    20.92   998.0      67.10  11.0
# 4           5.70  2015.0      30000    22.77  1498.0      98.59   8.0
#
#       make                                      model  Individual  \
# 0   MARUTI                                   ALTO STD           1
# 1  HYUNDAI                             GRAND I10 ASTA           1
# 2  HYUNDAI                                   I20 ASTA           1
# 3   MARUTI                     ALTO K10 2010-2014 VXI           1
# 4     FORD  ECOSPORT 2015-2021 1.5 TDCI TITANIUM BSIV           0
#
#    Trustmark Dealer  Diesel  Electric  LPG  Petrol  Manual  5  >5  \
# 0                 0       0         0    0       1       1  1   0
# ...

# %%
df['full_name']
# Out:
# 0                                       MARUTI ALTO STD
# 1                                HYUNDAI GRAND I10 ASTA
# 2                                      HYUNDAI I20 ASTA
# 3                         MARUTI ALTO K10 2010-2014 VXI
# 4        FORD ECOSPORT 2015-2021 1.5 TDCI TITANIUM BSIV
#                               ...
# 19815                     TOYOTA PLATINUM ETIOS 1.4 GXD
# 19816                            MARUTI ERTIGA BSIV VXI
# 19817                      SKODA RAPID 1.5 TDI ELEGANCE
# 19818                            MAHINDRA XUV500 W6 2WD
# 19819                          HONDA CITY I-VTEC CVT VX
# Name: full_name, Length: 19820, dtype: object

# %%
display(df.describe())
# Out:
#        selling_price          year     km_driven       mileage        engine  \
# count   19820.000000  19820.000000  1.982000e+04  19820.000000  19820.000000
# mean        6.585509   2014.561453  5.815856e+04     19.503402   1475.702381
# std         4.847364      3.196636  5.171563e+04      4.297784    518.571223
# min         0.300000   1992.000000  1.000000e+02      4.000000      0.000000
# 25%         3.410000   2013.000000  3.100000e+04     16.950000   1197.000000
# 50%         5.200000   2015.000000  5.200000e+04     19.300000   1248.000000
# 75%         7.850000   2017.000000  7.400000e+04     22.320000   1582.000000
# max        20.902500   2021.000000  3.800000e+06    120.000000   6752.000000
#
#           max_power           age    Individual  Trustmark Dealer  \
# count  19820.000000  19820.000000  19820.000000      19820.000000
# mean      98.122907      8.438547      0.390666          0.009586
# std       44.761727      3.196636      0.487912          0.097442
# ...

# %%
df.mileage.hist()
# Out:
# <Axes: >

# %% [markdown]
# #### Here Mileagu is not fill properly
#
# 1. we have to remove the record with 0
# 2. Impute their mileage values by taking mean of the make and model

# %%
df[df['mileage']==0.0].shape
# Out:
# (0, 19)

# %%
df = df.drop(df[df['mileage'] == 0.0].index, axis=0)

# %% [markdown]
# <b>Are the top values errorneous?</b>

# %%
df[df['mileage']>40]
# Out:
#        selling_price    year  km_driven  mileage       engine  max_power  \
# 11879           4.00  2018.0      26000    110.0  1476.327401       25.4
# 15572           3.60  2015.0      42862    120.0     0.000000       25.5
# 17648           4.50  2015.0      40000    120.0     0.000000       25.5
# 18261           3.25  2013.0      50000    120.0     0.000000       25.5
#
#         age      make        model  Individual  Trustmark Dealer  Diesel  \
# 11879   5.0  MAHINDRA   E2OPLUS P6           0                 0       0
# 15572   8.0  MAHINDRA       E2O T2           0                 0       0
# 17648   8.0  MAHINDRA       E2O T2           0                 0       0
# 18261  10.0  MAHINDRA  E2O PREMIUM           1                 0       0
#
#        Electric  LPG  Petrol  Manual  5  >5             full_name
# 11879         1    0       0       0  0   0   MAHINDRA E2OPLUS P6
# 15572         1    0       0       0  1   0       MAHINDRA E2O T2
# ...

# %% [markdown]
# <b>This is are not error its electric engine(EV)</b>

# %%
numeric_df = df.select_dtypes(include=[np.number])

plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# <b>Engine</b> and <b>Max power</b> are very corelated to selling price

# %%
sns.pairplot(df, y_vars=["selling_price"])

# %% [markdown]
# ##### Here check each type of entity
#
# 1. Different type of seller
# 2. type of transmission
# 3. Differnet fuel type
